# %% [markdown]
# # Setup

# %%
# enable to reimport modules
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_columns = 999

# %%
from scripts.feature import FeatureFactory
ff = FeatureFactory()
ff.feature_list()
# Out:
# ['MoleculeCount', 'MoleculeDistanceStatistics', 'Atom0Count', 'Atom1Count']

# %%
from scripts.experiment import Experiment
ex = Experiment()
y_pred = ex.run()
# Out:
# [autoreload of scripts.model failed: Traceback (most recent call last):
#   File "/Users/shohei_goda/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/shohei_goda/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/shohei_goda/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/shohei_goda/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 289, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/shohei_goda/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
# ...

# %%
X_train.head(1)
# Out:
#                                             id  molecule_dist_mean  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000001 0            1             10            1.506668
#
#                                             molecule_dist_min  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000001 0            1                      1.091946
#
#                                             molecule_dist_max  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000001 0            1                      1.783158
#
#                                             atom_0_couples_count  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000001 0            1                                4
#
#                                             atom_1_couples_count
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000001 0            1                                4

# %%
y_train.head(1)
# Out:
#                                                  fc  type
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0             83.0224  1JHC

# %%
X_test.head(1)
# Out:
#                                             id  molecule_dist_mean  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000004 0            2              5            1.993966
#
#                                             molecule_dist_min  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000004 0            2                      1.062099
#
#                                             molecule_dist_max  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000004 0            2                      3.323277
#
#                                             atom_0_couples_count  \
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000004 0            2                                3
#
#                                             atom_1_couples_count
# molecule_name    atom_index_1 atom_index_0
# dsgdb9nsd_000004 0            2                                2

# %%
dataset.train.head(1)
# Out:
#                                             id  type  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0              0  1JHC
#
#                                             scalar_coupling_constant  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0                              84.8076
#
#                                             atom_index_x atom_0      x_0  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0                        1      H  0.00215
#
#                                                  y_0       z_0  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0            -0.006031  0.001976
#
#                                             electronegativity_x  radius_x  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0                             2.2      0.43
#
# ...

# %%
dataset.test.head(1)
# Out:
#                                                  id  type  atom_index_x  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000004 2            0             4658147  2JHC             2
#
#                                            atom_0       x_0  y_0  z_0  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000004 2            0                 H -1.661639  0.0  1.0
#
#                                             electronegativity_x  radius_x  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000004 2            0                             2.2      0.43
#
#                                             bond_lengths_mean_x    ...      \
# molecule_name    atom_index_0 atom_index_1                         ...
# dsgdb9nsd_000004 2            0                        1.062099    ...
#
#                                             atom_index_y  atom_1       x_1  \
# molecule_name    atom_index_0 atom_index_1
# ...

# %%
dataset.submission.head(1)
# Out:
#         id  scalar_coupling_constant
# 0  4658147                         0

# %%
dataset.dipole_moments.head(1)
# Out:
#                     X    Y    Z
# molecule_name
# dsgdb9nsd_000001  0.0  0.0  0.0

# %%
dataset.magnetic_shielding_tensors.head(1)
# Out:
#                   atom_index       XX   YX      ZX   XY       YY      ZY  \
# molecule_name
# dsgdb9nsd_000001           0  195.315  0.0 -0.0001  0.0  195.317  0.0007
#
#                       XZ      YZ       ZZ
# molecule_name
# dsgdb9nsd_000001 -0.0001  0.0007  195.317

# %%
dataset.mulliken_charges.head(1)
# Out:
#                   atom_index  mulliken_charge
# molecule_name
# dsgdb9nsd_000001           0        -0.535689

# %%
dataset.potential_energy.head(1)
# Out:
#                   potential_energy
# molecule_name
# dsgdb9nsd_000001         -40.52368

# %%
dataset.scalar_coupling_contributions.head(1)
# Out:
#                                             type       fc        sd      pso  \
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0             1JHC  83.0224  0.254579  1.25862
#
#                                                 dso
# molecule_name    atom_index_0 atom_index_1
# dsgdb9nsd_000001 1            0             0.27201

# %%
dataset.structures.head(1)
# Out:
#                   atom_index atom         x         y         z  \
# molecule_name
# dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
#
#                   electronegativity  radius  bond_lengths_mean  \
# molecule_name
# dsgdb9nsd_000001               2.55    0.82            1.09195
#
#                   bond_lengths_std  n_bonds
# molecule_name
# dsgdb9nsd_000001          0.000003        4
