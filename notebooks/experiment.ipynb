# %% [markdown]
# # Setup

# %%
# enable to reimport modules
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from scripts.feature import FeatureFactory

# %%
ff = FeatureFactory()
ff.feature_list()
# Out:
# ['Type', 'Type0', 'Type1', 'Atom0', 'Atom1']

# %%
from scripts import experiment
dataset = experiment.run()
# Out:
# load the dataset pickle

# %%
dataset.train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant  atom_index_x atom_0       x_0       y_0  ...  \
# 0                   84.8076             1      H  0.002150 -0.006031  ...
# 1                  -11.2570             1      H  0.002150 -0.006031  ...
# 2                  -11.2548             1      H  0.002150 -0.006031  ...
# 3                  -11.2543             1      H  0.002150 -0.006031  ...
# 4                   84.8074             2      H  1.011731  1.463751  ...
#
#    atom_index_y  atom_1       x_1       y_1       z_1  electronegativity_y  \
# 0             0       C -0.012698  1.085804  0.008001                 2.55
# 1             2       H  1.011731  1.463751  0.000277                 2.20
# 2             3       H -0.540815  1.447527 -0.876644                 2.20
# 3             4       H -0.523814  1.437933  0.906397                 2.20
# 4             0       C -0.012698  1.085804  0.008001                 2.55
#
#    radius_y n_bonds_y  bond_lengths_mean_y  bond_lengths_std_y
# 0      0.82         4             1.091950            0.000003
# 1      0.43         1             1.091952            0.000000
# 2      0.43         1             1.091946            0.000000
# 3      0.43         1             1.091948            0.000000
# 4      0.82         4             1.091950            0.000003
#
# [5 rows x 26 columns]

# %%
dataset.test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type  atom_index_x  \
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC             2
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC             2
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH             2
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC             3
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC             3
#
#   atom_0       x_0  y_0  z_0  ...  atom_index_y  atom_1       x_1  y_1  z_1  \
# 0      H -1.661639  0.0  1.0  ...             0       C  0.599539  0.0  1.0
# 1      H -1.661639  0.0  1.0  ...             1       C -0.599539  0.0  1.0
# 2      H -1.661639  0.0  1.0  ...             3       H  1.661639  0.0  1.0
# 3      H  1.661639  0.0  1.0  ...             0       C  0.599539  0.0  1.0
# 4      H  1.661639  0.0  1.0  ...             1       C -0.599539  0.0  1.0
#
#    electronegativity_y radius_y  n_bonds_y  bond_lengths_mean_y  \
# 0                 2.55     0.82          2             1.130589
# 1                 2.55     0.82          2             1.130589
# 2                 2.20     0.43          1             1.062099
# 3                 2.55     0.82          2             1.130589
# 4                 2.55     0.82          2             1.130589
#
#    bond_lengths_std_y
# 0             0.06849
# 1             0.06849
# 2             0.00000
# 3             0.06849
# 4             0.06849
#
# [5 rows x 25 columns]

# %%
dataset.structures.head()
# Out:
#       molecule_name  atom_index atom         x         y         z  \
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
#
#    electronegativity  radius  n_bonds  bond_lengths_mean  bond_lengths_std
# 0               2.55    0.82        4           1.091950          0.000003
# 1               2.20    0.43        1           1.091953          0.000000
# 2               2.20    0.43        1           1.091952          0.000000
# 3               2.20    0.43        1           1.091946          0.000000
# 4               2.20    0.43        1           1.091948          0.000000

# %%
dataset.scalar_coupling_contributions.head()
# Out:
#       molecule_name  atom_index_0  atom_index_1  type       fc        sd  \
# 0  dsgdb9nsd_000001             1             0  1JHC  83.0224  0.254579
# 1  dsgdb9nsd_000001             1             2  2JHH -11.0347  0.352978
# 2  dsgdb9nsd_000001             1             3  2JHH -11.0325  0.352944
# 3  dsgdb9nsd_000001             1             4  2JHH -11.0319  0.352934
# 4  dsgdb9nsd_000001             2             0  1JHC  83.0222  0.254585
#
#        pso       dso
# 0  1.25862  0.272010
# 1  2.85839 -3.433600
# 2  2.85852 -3.433870
# 3  2.85855 -3.433930
# 4  1.25861  0.272013

# %%
dataset.structures.head()
# Out:
#       molecule_name  atom_index atom         x         y         z  \
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
#
#    electronegativity  radius  n_bonds  bond_lengths_mean  bond_lengths_std
# 0               2.55    0.82        4           1.091950          0.000003
# 1               2.20    0.43        1           1.091953          0.000000
# 2               2.20    0.43        1           1.091952          0.000000
# 3               2.20    0.43        1           1.091946          0.000000
# 4               2.20    0.43        1           1.091948          0.000000
