# %% [markdown]
# # Setup

# %%
# enable to reimport modules
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from scripts.feature import FeatureFactory

# %%
ff = FeatureFactory()
ff.feature_list()
# Out:
# ['Type', 'Type0', 'Type1', 'Atom0', 'Atom1']

# %%
import scripts.experiment
dataset = experiment.run()

# %%
from scripts.data import DatasetCreator
creator = DatasetCreator()
dataset = creator.run()
# Out:
# ../data/pickle/dataset.pkl
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-57-1e138c8474e3> in <module>()
#       1 from scripts.data import DatasetCreator
#       2 creator = DatasetCreator()
# ----> 3 dataset = creator.run()
#
# ~/Desktop/Shohei/Python/Kaggle/CHAMPS/notebooks/scripts/data.py in run(self)
#      43
#      44         # save dataset object to pickle
# ---> 45         dataset.save(self.config.pickle_dir)
#      46         return dataset
#      47
#
# ~/Desktop/Shohei/Python/Kaggle/CHAMPS/notebooks/scripts/data.py in save(self, dir)
#      73         os.makedirs(dir, exist_ok=True)
#      74         print(os.path.join(dir, "dataset.pkl"))
# ---> 75         pickle.dump(self, open(os.path.join(dir, "dataset.pkl"), "wb"))
#      76         print("save the dataset pickle")
#      77
#
# OSError: [Errno 22] Invalid argument

# %%
dataset.train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074

# %%
dataset.train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074

# %%
dataset.test.head()
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC

# %%
dataset.structures.head()
# Out:
#       molecule_name  atom_index atom         x         y         z  \
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
#
#    electronegativity  radius  bond_lengths_mean  bond_lengths_std  n_bonds
# 0               2.55    0.82           1.091950          0.000003        4
# 1               2.20    0.43           1.091953          0.000000        1
# 2               2.20    0.43           1.091952          0.000000        1
# 3               2.20    0.43           1.091946          0.000000        1
# 4               2.20    0.43           1.091948          0.000000        1

# %%
dataset.scalar_coupling_contributions.head()
# Out:
#       molecule_name  atom_index_0  atom_index_1  type       fc        sd  \
# 0  dsgdb9nsd_000001             1             0  1JHC  83.0224  0.254579
# 1  dsgdb9nsd_000001             1             2  2JHH -11.0347  0.352978
# 2  dsgdb9nsd_000001             1             3  2JHH -11.0325  0.352944
# 3  dsgdb9nsd_000001             1             4  2JHH -11.0319  0.352934
# 4  dsgdb9nsd_000001             2             0  1JHC  83.0222  0.254585
#
#        pso       dso
# 0  1.25862  0.272010
# 1  2.85839 -3.433600
# 2  2.85852 -3.433870
# 3  2.85855 -3.433930
# 4  1.25861  0.272013

# %%
dataset.structures.head()
# Out:
#       molecule_name  atom_index atom         x         y         z  \
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
#
#    electronegativity  radius  bond_lengths_mean  bond_lengths_std  n_bonds
# 0               2.55    0.82           1.091950          0.000003        4
# 1               2.20    0.43           1.091953          0.000000        1
# 2               2.20    0.43           1.091952          0.000000        1
# 3               2.20    0.43           1.091946          0.000000        1
# 4               2.20    0.43           1.091948          0.000000        1
